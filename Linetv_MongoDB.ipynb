# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://chou1998:king1998@cluster0.h9aoseu.mongodb.net/?retryWrites=true&w=majority")
db = client.anime
collection = db.anime_bl

for i in j_d["data"]:
    for t in i["genre"]:
        if t["key"] == "耽美":
            temp_lang = ""
            temp_y = []
            if "\t" in i["name"]:
                temp_name = i["name"].replace('\t', ' ')
            elif "\xa0" in i["name"]:
                temp_name = i["name"].replace('\xa0', ' ')
            else:
                temp_name = i["name"] #劇名
            
            for j in i['genre']:
                if j['genreCategoryName'] == "出品地":
                    temp_lang += j["key"] + " "
            
            for t in i["genre"]:
                if t["id"] >= 382 and t["id"] <= 392:
                    temp_y.append(t["key"])
            for t in i["genre"]:
                if t["id"] == 417 or t["id"] == 374:
                    temp_vip = t["key"]
            
            if len(temp_y) == 1:
                year = temp_y[0]
            elif len(temp_y) == 2:
                year = temp_y[1]
            
            temp_insert = {
                "url": "https://www.linetv.tw/drama/" + str(i["contentId"]),#劇網址
                "劇照": i["portraitPosterUrl"],
                "劇名": temp_name,
                "認證起始時間": i["authorizedStartAt"],
                "認證結束時間": i["authorizedEndAt"],
                "平台推出時間": i["publishedStartAt"],
                "平台結束時間": i["publishedEndAt"],
                "觀看次數(Last 7 day)": i["viewCount"]['last7Days'],
                "觀看次數(total)": i["viewCount"]['total'],
                "評分": round(i["userRatingAvg"], 2),
                "評分人數": i["userRatingCount"],
                "分級": i["contentRating"]["name"],
                "最小觀看年紀": i["contentRating"]["minAge"],
                "年份": year,
                "VIP": temp_vip,
                "出品地/語言": temp_lang[:-1],
                "簡介": i['introduction']
            }
            result = collection.insert_one(temp_insert)
            print(result)
            break
# Out:
# <pymongo.results.InsertOneResult object at 0x0000024EB09E1B80>
# <pymongo.results.InsertOneResult object at 0x0000024EB0A37280>
# <pymongo.results.InsertOneResult object at 0x0000024EB09E1A00>
# <pymongo.results.InsertOneResult object at 0x0000024EB0A371F0>
# <pymongo.results.InsertOneResult object at 0x0000024EB0B0BC10>
# <pymongo.results.InsertOneResult object at 0x0000024EB0A371F0>
# <pymongo.results.InsertOneResult object at 0x0000024EB09E1A00>
# <pymongo.results.InsertOneResult object at 0x0000024EB0A37280>
# <pymongo.results.InsertOneResult object at 0x0000024EB09E1EB0>
# <pymongo.results.InsertOneResult object at 0x0000024EB0A37AC0>
# <pymongo.results.InsertOneResult object at 0x0000024EB09E1B80>

# %%
import json
with open("..\\api_json\\api_linetv_anime.json", encoding='utf-8') as f:
    j_d = json.load(f)
print(j_d)
# Out:
# {'code': 0, 'message': 'query success', 'total': 944, 'took': 47, 'data': [{'genre': [{'id': 11, 'key': '友情', 'name': '友情', 'alternative': '友情', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 2, 'genreCategoryName': '情感'}, {'id': 38, 'key': '懸疑', 'name': '懸疑', 'alternative': '懸疑', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 160, 'key': '恐怖', 'name': '恐怖', 'alternative': '恐怖', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 162, 'key': '格鬥', 'name': '格鬥', 'alternative': '格鬥', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 191, 'key': '日本', 'name': '日本', 'alternative': '日本', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 8, 'genreCategoryName': '出品地'}, {'id': 209, 'key': '熱血', 'name': '熱血', 'alternative': '熱血', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 212, 'key': '王道', 'name': '王道', 'alternative': '王道', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 215, 'key': '妖怪', 'name': '妖怪', 'alternative': '妖怪', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 7, 'genreCategoryName': '角色'}, {'id': 230, 'key': '幽默', 'name': '幽默', 'alternative': '幽默', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 374, 'key': '免費', 'name': '免費', 'alternative': '免費', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 14, 'genreCategoryName': '付費資格'}, {'id': 390, 'key': '2021', 'name': '2021', 'alternative': '2021', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 9, 'genreCategoryName': '年份'}], 'character': [{'id': 22216, 'name': '外崎春雄', 'actorId': 9761, 'actorName': '外崎春雄', 'actorAvatarUrl': 'http'}], 'episodePublishStatus': [{'episode': 11, 'level': 2, 'lastPublishAt': '2021-12-31T16:00:00.000Z'}], 'label': [{'id': 2, 'order': 0, 'title': '1080P', 'rgb': '626262', 'alpha': 'FF', 'textRgb': 'FFFFFF'}], 'channel': [{'id': 2, 'name': '動漫', 'priority': 2, 'status': 1}], 'package': [{'id': 1, 'accessLevel': 2, 'name': 'VIP 全餐'}], 'contentId': '12901', 'releaseAt': '2021-12-31T23:59:59.000Z', 'type': 'drama', 'createdAt': '2021-12-01T07:17:32.000Z', 'updatedAt': '2022-03-01T17:50:49.000Z', 'contentInfoId': 280490, 'name': '鬼滅之刃 遊郭篇', 'introduction': '炭治郎他們跟著「音柱」宇髓天元一起前往鬼棲息的花街柳巷。天元3位身為女忍者的老婆，前往該處收集情報時失蹤了。炭治郎他們為了進行調查而男扮女裝潛入，卻始終找不到鬼的棲息地。就在此時，鬼的魔掌伸向花魁們！炭治郎一行人能夠找到鬼嗎？', 'announcement': '', 'landscapePosterUrl': 'https://img.linetv.tw/medium/drama/12901-b_211229.jpg', 'portraitPosterUrl': 'https://img.linetv.tw/medium/drama/12901-p_211229.jpg', 'region': {'id': 228, 'name': '台灣', 'code': 'TW'}, 'authPlatform': ['web', 'mobile'], 'authorized': True, 'authorizedStartAt': '2021-12-16T10:57:46.000Z', 'authorizedEndAt': '2024-06-30T15:59:00.000Z', 'published': True, 'publishedStartAt': '2021-12-31T16:00:00.000Z', 'publishedEndAt': '2024-06-30T15:59:00.000Z', 'totalEpisodes': 11, 'visibleEpisodes': 11, 'publishStatusLabel': '', 'viewCount': {'total': 3119767.3111788323, 'last7Days': 6096620}, 'userRatingAvg': 4.943820224719101, 'userRatingCount': 178, 'contentRating': {'id': 3, 'name': '輔導十二歲級', 'minAge': 12}, 'svod': True}, {'genre': [{'id': 10, 'key': '家庭', 'name': '家庭', 'alternative': '家庭', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 1, 'genreCategoryName': '地點'}, {'id': 162, 'key': '格鬥', 'name': '格鬥', 'alternative': '格鬥', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 191, 'key': '日本', 'name': '日本', 'alternative': '日本', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 8, 'genreCategoryName': '出品地'}, {'id': 230, 'key': '幽默', 'name': '幽默', 'alternative': '幽默', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 10, 'genreCategoryName': '特色'}, {'id': 374, 'key': '免費', 'name': '免費', 'alternative': '免費', 'correlation': 10, 'visibility': 1, 'genreCategoryId': 14, 'genreCategoryName': '付費資格'}, {'i ...

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://chou1998:king1998@cluster0.h9aoseu.mongodb.net/?retryWrites=true&w=majority")
db = client.anime
collection = db.anime_family
t = 0
# result = list(collection.find(
#     {"name": { "$regex" : "Chou"}} #模糊搜尋
# ))
# gt 大於 gte 大於等於 lt 小於 lte 小於等於
results = list(collection.find(
    {"評分": {"$gt": 4.5, "$lte": 5}}
))

print(results[0]["劇名"])
# Out:
# 鬼滅之刃劇場版：無限列車篇

# %%
import pymongo
from flask import Flask, request
from linebot import LineBotApi, WebhookHandler
from linebot.models import FlexSendMessage, TextSendMessage, ImageSendMessage
import random
import requests as req
from bs4 import BeautifulSoup
import json

# LINE 聊天機器人的基本資料
line_bot_api = LineBotApi('5nYbd+XB+lJGCv7EVzCLhsWWI2lKauWR1A4u41aXGzSwjaMYX8PkGtnJiod3yOyvIzKmHDDLtffsaaKTiV7aADhyJzOHqIsIDFkVnj2920dHl/x+xBKXogTnJMWxpO/BhBGt5ko3svQbfeCnrcO/CAdB04t89/1O/w1cDnyilFU=')
client = pymongo.MongoClient("mongodb+srv://chou1998:king1998@cluster0.h9aoseu.mongodb.net/?retryWrites=true&w=majority")

def top10(tk):
    res = req.get("https://www.linetv.tw/")
    soup = BeautifulSoup(res.text)
    j = json.loads(soup.find("script").text[27:])
    count = 0
    r = []
    for d in j['ssrData']['https://api.linetv.tw/v2/index'][11]["datas"]:
        r.append([d["data"]["posterUrl"], "https://www.linetv.tw/drama/"+ str(d["data"]["id"]), d["data"]["name"]]) #圖片網址 網址 劇名
        count += 1
        if count == 10:
            break
    line_bot_api.reply_message(tk, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[0][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[0][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.1",
            "contents": []
          },
          {
            "type": "text",
            "text": r[0][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[0][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[1][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[1][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.2",
            "contents": []
          },
          {
            "type": "text",
            "text": r[1][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[1][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[2][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[2][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.3",
            "contents": []
          },
          {
            "type": "text",
            "text": r[2][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[2][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[3][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[3][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.4",
            "contents": []
          },
          {
            "type": "text",
            "text": r[3][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[3][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[4][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[4][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.5",
            "contents": []
          },
          {
            "type": "text",
            "text": r[4][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[4][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[5][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[5][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.6",
            "contents": []
          },
          {
            "type": "text",
            "text": r[5][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[5][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[6][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[6][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.7",
            "contents": []
          },
          {
            "type": "text",
            "text": r[6][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[6][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[7][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[7][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.8",
            "contents": []
          },
          {
            "type": "text",
            "text": r[7][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[7][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[8][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[8][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.9",
            "contents": []
          },
          {
            "type": "text",
            "text": r[8][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[8][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[9][0],
        "size": "full",
        "aspectRatio": "30:20",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[9][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "No.10",
            "contents": []
          },
          {
            "type": "text",
            "text": r[9][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "速速看劇去",
              "uri": r[9][1]
            },
            "height": "sm",
            "style": "link"
          }
        ]
      }
    }
  ]
}
))
    
def reply(tk, rc):
    print("in reply")
    r = []
    top = 5
    down = 4.5
    results = list(rc.find(
        {"評分": {"$gt": down, "$lte": top}}
    ))
    if not len(results):
        while len(r) < 5 and top > 0:
            top -= 0.5
            down -= 0.5
            results = list(rc.find(
                {"評分": {"$gt": down, "$lte": top}}
            ))
            if len(results):
                for t in results:
                    r.append([t["劇照"], t["url"], t["劇名"]])
    else :
        for t in results:
            r.append([t["劇照"], t["url"], t["劇名"]])
        while len(r) < 5 and top > 0:
            top -= 0.5
            down -= 0.5
            results = list(rc.find(
                {"評分": {"$gt": down, "$lte": top}}
            ))
            if len(results):
                for t in results:
                    r.append([t["劇照"], t["url"], t["劇名"]])
    r = random.sample(r, len(r))
    if len(r) >= 5:
        r = r[:5]
        line_bot_api.reply_message(tk, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[0][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[0][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[0][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[0][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[1][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[1][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[1][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[1][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[2][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[2][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[2][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[2][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[3][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[3][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[3][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[3][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[4][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[4][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[4][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[4][1]
            }
          }
        ]
      }
    }
  ]
})) # 5
    elif len(r) == 4:
        r = r[:4]
        line_bot_api.reply_message(tk, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[0][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[0][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[0][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[0][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[1][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[1][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[1][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[1][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[2][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[2][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[2][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[2][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[3][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[3][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[3][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[3][1]
            }
          }
        ]
      }
    }
  ]
})) # 4
    elif len(r) == 3:
        r = r[:3]
        line_bot_api.reply_message(tk, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[0][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[0][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[0][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[0][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[1][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[1][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[1][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[1][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[2][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[2][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[2][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[2][1]
            }
          }
        ]
      }
    }
  ]
})) # 3
    elif len(r) == 2:
        r = r[:2]
        line_bot_api.reply_message(tk, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[0][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[0][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[0][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[0][1]
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[1][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[1][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[1][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[1][1]
            }
          }
        ]
      }
    }
  ]
})) # 2
    elif len(r) == 1:
        line_bot_api.reply_message(tk, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": r[0][0],
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Line",
          "uri": r[0][1]
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": r[0][2],
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "flex": 0,
        "spacing": "sm",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "迫不及待追起來",
              "uri": r[0][1]
            }
          }
        ]
      }
    }
  ]
})) # 1
    else:
        line_bot_api.reply_message(tk, TextSendMessage("很抱歉！目前此種類沒有影片！")) # none
    
    
def drama(text, rtk):
    drama_list = ["職場","校園","家庭","古裝","愛情","都會","改編","甜寵","懸疑","喜劇","勵志","BL","奇幻","在地","驚悚","療癒","仙俠","穿越","時代"]
    if text not in drama_list:
        line_bot_api.reply_message(rtk, TextSendMessage("請輸入正確選單格式！"))
    else:
        db = client.drama
        if text == "職場":
            c = db.drama_workplace
        elif text == "校園":
            c = db.drama_school
        elif text == "家庭":
            c = db.drama_family
        elif text == "古裝":
            c = db.drama_costume
        elif text == "愛情":
            c = db.drama_love
        elif text == "都會":
            c = db.drama_city
        elif text == "改編":
            c = db.drama_adaptation
        elif text == "甜寵":
            c = db.drama_sweet
        elif text == "懸疑":
            c = db.drama_suspenseful
        elif text == "喜劇":
            c = db.drama_comedy
        elif text == "勵志":
            c = db.drama_inspirational
        elif text == "BL":
            c = db.drama_bl
        elif text == "奇幻":
            c = db.drama_fantasy
        elif text == "在地":
            c = db.drama_local
        elif text == "驚悚":
            c = db.drama_thriller
        elif text == "療癒":
            c = db.drama_heal
        elif text == "仙俠":
            c = db.drama_chivalrous
        elif text == "穿越":
            c = db.drama_time_travel
        elif text == "時代":
            c = db.drama_period
        reply(rtk, c)

def movie(text, rtk):
    movie_list = ["愛情","情慾","驚悚","動作","歷史","喜劇","勵志","犯罪","靈異","懸疑","奇幻","影展","家庭","職場","青春","動畫","戰爭","劇情","科幻","紀錄片","LGBTQ"]
    if text not in movie_list:
        line_bot_api.reply_message(rtk, TextSendMessage("請輸入正確選單格式！"))
    else:
        db = client.movie
        if text == "愛情":
            c = db.movie_love
        elif text == "情慾":
            c = db.movie_sex
        elif text == "驚悚":
            c = db.movie_thriller
        elif text == "動作":
            c = db.movie_action
        elif text == "歷史":
            c = db.movie_history
        elif text == "喜劇":
            c = db.movie_comedy
        elif text == "勵志":
            c = db.movie_insprirational
        elif text == "犯罪":
            c = db.movie_crime
        elif text == "靈異":
            c = db.movie_supernatural
        elif text == "懸疑":
            c = db.movie_suspenseful
        elif text == "奇幻":
            c = db.movie_fantasy
        elif text == "影展":
            c = db.movie_film_festival
        elif text == "家庭":
            c = db.movie_family
        elif text == "職場":
            c = db.movie_workplace
        elif text == "青春":
            c = db.movie_young
        elif text == "動畫":
            c = db.movie_animation
        elif text == "戰爭":
            c = db.movie_war
        elif text == "劇情":
            c = db.movie_plot
        elif text == "科幻":
            c = db.movie_fiction
        elif text == "紀錄片":
            c = db.movie_documentary
        elif text == "LGBTQ":
            c = db.movie_lgbtq
        reply(rtk, c)

def variety(text, rtk):
    variety_list = ["益智","選秀","美食","歌唱","文化","鄉土","實境","脫口秀","短劇","偶像","素人","紀實","新聞","外景"]
    if text not in variety_list:
        line_bot_api.reply_message(rtk, TextSendMessage("請輸入正確選單格式！"))
    else:
        db = client.variety
        if text == "益智":
            c = db.variety_puzzle
        elif text == "選秀":
            c = db.variety_talent
        elif text == "美食":
            c = db.variety_food
        elif text == "歌唱":
            c = db.variety_sing
        elif text == "文化":
            c = db.variety_culture
        elif text == "鄉土":
            c = db.variety_local
        elif text == "實境":
            c = db.variety_live
        elif text == "脫口秀":
            c = db.variety_talkshow
        elif text == "短劇":
            c = db.variety_skit
        elif text == "偶像":
            c = db.variety_idol
        elif text == "素人":
            c = db.variety_talent
        elif text == "紀實":
            c = db.variety_documentary
        elif text == "新聞":
            c = db.variety_news
        elif text == "外景":
            c = db.variety_location
        reply(rtk, c)

def edu(text, rtk):
    edu_list = ["卡通","日常","教育","喜劇","冒險","家庭","校園","友情","職場"]
    if text not in edu_list:
        line_bot_api.reply_message(rtk, TextSendMessage("請輸入正確選單格式！"))
    else:
        db = client.edu
        if text == "卡通":
            c = db.edu_cartoon
        elif text == "日常":
            c = db.edu_daily
        elif text == "教育":
            c = db.edu_educate
        elif text == "喜劇":
            c = db.edu_comedy
        elif text == "冒險":
            c = db.edu_adventure
        elif text == "家庭":
            c = db.edu_family
        elif text == "校園":
            c = db.edu_school
        elif text == "友情":
            c = db.edu_friendship
        elif text == "職場":
            c = db.edu_workplace
        reply(rtk, c)

def anime(text, rtk):
    anime_list = ["Ani-One","熱血","王道","懸疑","勵志","科幻","青春","幽默","校園","料理","格鬥","家庭","友情","愛情","運動","妖怪","恐怖","職人","耽美"]
    if text not in anime_list:
        line_bot_api.reply_message(rtk, TextSendMessage("請輸入正確選單格式！"))
    else:
        db = client.anime
        if text == "Ani-One":
            c = db.anime_ani_one
        elif text == "熱血":
            c = db.anime_passionate
        elif text == "王道":
            c = db.anime_popularity
        elif text == "懸疑":
            c = db.anime_suspenseful
        elif text == "勵志":
            c = db.anime_inspirational
        elif text == "科幻":
            c = db.anime_fiction
        elif text == "青春":
            c = db.anime_young
        elif text == "幽默":
            c = db.anime_humor
        elif text == "校園":
            c = db.anime_school
        elif text == "料理":
            c = db.anime_cook
        elif text == "格鬥":
            c = db.anime_fighting
        elif text == "家庭":
            c = db.anime_family
        elif text == "友情":
            c = db.anime_friendship
        elif text == "愛情":
            c = db.anime_love
        elif text == "運動":
            c = db.anime_sports
        elif text == "妖怪":
            c = db.anime_monster
        elif text == "恐怖":
            c = db.anime_horror
        elif text == "職人":
            c = db.anime_craftsman
        elif text == "耽美":
            c = db.anime_bl
        reply(rtk, c)

app = Flask(__name__)
@app.route("/", methods=['POST'])
def verify():
    data = request.get_json()
    print(data)
    
    temp_text = data['events'][0]['message']['text'] #抓回覆文字
    retoken = data['events'][0]['replyToken']
    
    if temp_text == "快推坑我":
        top10(retoken) #Line TV 爬蟲前10名
    elif temp_text == "VIP升級":
        line_bot_api.reply_message(retoken, TextSendMessage("https://www.linetv.tw/purchase/vip?source=NAVBAR")) #給VIP頁面連結
    elif temp_text == "活動":
        line_bot_api.reply_message(retoken, TextSendMessage("https://www.linetv.tw/feed/campaign?source=NAVBAR")) #給活動頁面連結
    elif temp_text =="我想知道更多劇":
        line_bot_api.reply_message(retoken, FlexSendMessage(alt_text='hello',contents={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://static-img.linetv....",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/1?channel_id=1&feed_id=13&source=CHANNEL_LIST_MENU"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/1?channel_id=1&feed_id=13&source=CHANNEL_LIST_MENU"
        },
        "contents": [
          {
            "type": "text",
            "text": "連續劇",
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "甜死人不償命",
              "text": "連續劇 甜寵"
            },
            "gravity": "bottom"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "腎上腺素飆升",
              "text": "連續劇 懸疑"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "笑顏逐開嘿嘿嘿",
              "text": "連續劇 喜劇"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "古裝cosplay最對味",
              "text": "連續劇 古裝"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "家家有本難念的經",
              "text": "連續劇 家庭"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://static-img.linetv....",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/6?channel_id=6&feed_id=18&source=CHANNEL_LIST_MENU"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/6?channel_id=6&feed_id=18&source=CHANNEL_LIST_MENU"
        },
        "contents": [
          {
            "type": "text",
            "text": "電影",
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "各種愛情的模樣",
              "text": "電影 愛情"
            },
            "gravity": "bottom"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "來個緊張刺激的",
              "text": "電影 驚悚"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "赫赫哈ㄏㄧˋ",
              "text": "電影 動作"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "一起開心笑一個",
              "text": "電影 喜劇"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "不要做壞事啦",
              "text": "電影 犯罪"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://static-img.linetv....",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/3?channel_id=3&feed_id=15&source=CHANNEL_LIST_MENU"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/3?channel_id=3&feed_id=15&source=CHANNEL_LIST_MENU"
        },
        "contents": [
          {
            "type": "text",
            "text": "綜藝",
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "實境",
              "text": "綜藝 實境"
            },
            "gravity": "bottom"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "文化",
              "text": "綜藝 文化"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "偶像",
              "text": "綜藝 偶像"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "一起上山下海",
              "text": "綜藝 外景"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "歌唱",
              "text": "綜藝 歌唱"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://static-img.linetv....",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/2?channel_id=2&feed_id=14&source=CHANNEL_LIST_MENU"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/2?channel_id=2&feed_id=14&source=CHANNEL_LIST_MENU"
        },
        "contents": [
          {
            "type": "text",
            "text": "動漫",
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "熱血",
              "text": "動漫 熱血"
            },
            "gravity": "bottom"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "科幻",
              "text": "動漫 科幻"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "校園",
              "text": "動漫 校園"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "戀愛的臭酸味",
              "text": "動漫 愛情"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "妖怪",
              "text": "動漫 妖怪"
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://static-img.linetv....",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://www.linetv.tw/channel/1?channel_id=1&feed_id=13&source=CHANNEL_LIST_MENU"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        },
        "contents": [
          {
            "type": "text",
            "text": "育樂",
            "weight": "bold",
            "size": "xl",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "我挑給小孩看的",
              "text": "育樂 教育"
            },
            "gravity": "bottom"
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "卡通",
              "text": "育樂 卡通"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "家庭",
              "text": "育樂 家庭"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "校園",
              "text": "育樂 校園"
            }
          },
          {
            "type": "button",
            "action": {
              "type": "message",
              "label": "喜劇",
              "text": "育樂 喜劇"
            }
          }
        ]
      }
    }
  ]
})
) #給推薦類別選單
        
    elif temp_text.find(" ") > 0:
        temp_type = temp_text[:temp_text.find(" ")]
        temp_kind = temp_text[temp_text.find(" ") + 1:]
        if temp_type == "連續劇":
            drama(temp_kind, retoken)
        elif temp_type == "電影":
            movie(temp_kind, retoken)
        elif temp_type == "綜藝":
            variety(temp_kind, retoken)
        elif temp_type == "育樂":
            edu(temp_kind, retoken)
        elif temp_type == "動漫":
            anime(temp_kind, retoken)
        else :
            line_bot_api.reply_message(retoken, TextSendMessage("請輸入正確選單格式！")) #點擊類別選單錯誤
    else :
        #reply->請點選下方資訊欄
        line_bot_api.reply_message(retoken, TextSendMessage("請輸入：精選、VIP升級、活動，或是點選前面的選單！"))
    
    return 'OK',200

if __name__ == "__main__":
    app.run(port=3000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:3000/ (Press CTRL+C to quit)
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484945498663', 'text': '連續劇 甜寵'}, 'webhookEventId': '01GPZ4YK8HG5PMDDC6EDKR0XMH', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935146170, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': 'ac4d630543a143139f780a4ed402f756', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 13:59:07] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jan/2023 13:59:15] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484946114208', 'text': '連續劇 甜寵'}, 'webhookEventId': '01GPZ4YVY0GDTFACFGWD25GHEG', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935154697, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '7c22a765e51c4d328d611e7c6655269d', 'mode': 'active'}]}
# in reply
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484949972959', 'text': '快推坑我'}, 'webhookEventId': '01GPZ50FVVV8Q4BMFPDK5XYCXF', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935207808, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '915c5e11d660472b89d69a1c311bfaa3', 'mode': 'active'}]}
# 127.0.0.1 - - [17/Jan/2023 14:00:09] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jan/2023 14:00:27] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484951410622', 'text': '我很帥'}, 'webhookEventId': '01GPZ511PVD1NSB8YT9BYD22JJ', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935226555, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '03dfaeea2ad84b7b8fdbed4bae68fc98', 'mode': 'active'}]}
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484954054511', 'text': '連續劇 喜劇'}, 'webhookEventId': '01GPZ523DZ2EKF0QXNRSWKW8A9', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935261009, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '72ee0b7625d146d5adfb078e3924e487', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:01:01] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484959656182', 'text': '連續劇 古裝'}, 'webhookEventId': '01GPZ54AS4Z6HVFEH93G4WVT7X', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935333774, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': 'ca06d28e81d0449c9547ac4dc665df32', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:02:15] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484961250639', 'text': '快推坑我'}, 'webhookEventId': '01GPZ54YZQ8NPA1W6X672GYP91', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935354498, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '571c75ede96a4527b9dab5325ab1edaa', 'mode': 'active'}]}
# 127.0.0.1 - - [17/Jan/2023 14:02:36] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484966398458', 'text': '電影 動作'}, 'webhookEventId': '01GPZ56Z8CRWYGCFGVE52WWNBD', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935420446, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '15168d71fe7445f2b807ad728dd4a286', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:03:41] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jan/2023 14:03:49] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484967031521', 'text': '綜藝 外景'}, 'webhookEventId': '01GPZ5774GKA7K411KHQCMVBQP', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935428369, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': 'b2f100426484492b90428de188965333', 'mode': 'active'}]}
# in reply
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484975099728', 'text': '連續劇 懸疑'}, 'webhookEventId': '01GPZ5AEXPJ8A9ZCH4EQAET1B6', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935534727, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '8dc2807136eb434c87b185eb9add4c7c', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:05:35] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484976046592', 'text': '快推坑我'}, 'webhookEventId': '01GPZ5AVAARC44HMV95PCDAVXE', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935547428, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '504bbe2da6ec4bebb79151a227f845d3', 'mode': 'active'}]}
# 127.0.0.1 - - [17/Jan/2023 14:05:48] "POST / HTTP/1.1" 200 -
# [2023-01-17 14:06:11,186] ERROR in app: Exception on / [POST]
# Traceback (most recent call last):
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\pchou\AppData\Local\Temp\ipykernel_15732\2584688566.py", line 1915, in verify
#     anime(temp_kind, retoken)
# TypeError: anime() takes 1 positional argument but 2 were given
# 127.0.0.1 - - [17/Jan/2023 14:06:11] "POST / HTTP/1.1" 500 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484977745886', 'text': '動漫 校園'}, 'webhookEventId': '01GPZ5BHRPMYZBG35PGBW19J01', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935570205, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '53b06fe255054d51888b07e1da152060', 'mode': 'active'}]}
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484978973086', 'text': '綜藝 實境'}, 'webhookEventId': '01GPZ5C1T9141V39MAZ42BVT7S', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935586693, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': 'ed83689fc362412ab4f808283a9683dd', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:06:27] "POST / HTTP/1.1" 200 -
# [2023-01-17 14:10:55,552] ERROR in app: Exception on / [POST]
# Traceback (most recent call last):
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\pchou\AppData\Local\Temp\ipykernel_15732\2584688566.py", line 1915, in verify
#     anime(temp_kind, retoken)
# TypeError: anime() takes 1 positional argument but 2 were given
# 127.0.0.1 - - [17/Jan/2023 14:10:55] "POST / HTTP/1.1" 500 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17484998932257', 'text': '動漫 愛情'}, 'webhookEventId': '01GPZ5M7FJJ4DWDB88DJ9EN54W', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935854837, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '0e14c7087dd54057b5a5069df8db8c9e', 'mode': 'active'}]}
# [2023-01-17 14:11:11,961] ERROR in app: Exception on / [POST]
# Traceback (most recent call last):
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\pchou\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\pchou\AppData\Local\Temp\ipykernel_15732\2584688566.py", line 1915, in verify
#     anime(temp_kind, retoken)
# TypeError: anime() takes 1 positional argument but 2 were given
# 127.0.0.1 - - [17/Jan/2023 14:11:11] "POST / HTTP/1.1" 500 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17485000137360', 'text': '動漫 科幻'}, 'webhookEventId': '01GPZ5MQGNQV95JS2DM4EQ9W27', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935871082, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '2560ef30849c435780084a53cfc16b93', 'mode': 'active'}]}
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17485000824173', 'text': '綜藝 實境'}, 'webhookEventId': '01GPZ5N0K63M7EKVP6PBX68BMV', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935880298, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '15c3bff16c62426394e6e772a0e36a29', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:11:21] "POST / HTTP/1.1" 200 -
# {'destination': 'Ue64359147f328e67d8b211e8a8f21316', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '17485005188271', 'text': '育樂 校園'}, 'webhookEventId': '01GPZ5PT4KF7BQPEQ85WGT6R37', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1673935939492, 'source': {'type': 'user', 'userId': 'Uf6b13437fee5e479c8228ca062896148'}, 'replyToken': '55424be64356445fb590d6cc5e4c2265', 'mode': 'active'}]}
# in reply
# 127.0.0.1 - - [17/Jan/2023 14:12:20] "POST / HTTP/1.1" 200 -

# %%
import random
t = [1, 2, 3, 4, 5]
o = []
o.append(t)
print(o)
# Out:
# [[1, 2, 3, 4, 5]]
